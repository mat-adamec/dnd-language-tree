# %% [markdown]
# # Explanation
#
# This program generates a language tree for my Dungeons and Dragons world, Eashavar. It uses graphviz to visualize the tree. The results are a little messy, but sufficient for my purposes. The key below succinctly describes how languages evolved over time, including which languages are still extant in its present time.

# %% [markdown]
# ### KEY TO READ GRAPH
# ------------------
# Bold, square = root
#
# Diamond = language isolate; may have derivatives, but these are typically constructed
#
# Egg = constructed language
#
# Arrow = divergence
#
# Dot = modernization
#
# Diamond = mutually intelligible (transitive - if a parent is intelligible with a daughter, a daughter is intelligible with all siblings)
#
# Box = convergence or mixture, half-intelligible
#
# None = vague relation (magic)
#
# Curve = constructed
#
# Bold = language in standard use (most modern, used divergence, or broadest mutually intelligible node)

# %%
from graphviz import Digraph

#Set up graph. This is where most of the configuration happens.
dot = Digraph(comment='Language Tree', format='svg')
dot.attr(newrank='true', clusterrank='local')
dot.attr(rankdir='LR')
dot.attr(ranksep='1', nodesep='0.5')
dot.attr(label='Eashavar Language Tree', fontsize='48', labelloc='t')

# %% [markdown]
# Now we create subgraphs for each of the language roots, and proceed from there!

# %%
# Orc root.
with dot.subgraph(name='cluster_orc') as orc:
    orc.attr(label='')
    
    orc.node('orc', '<<b>ORCISH</b>>', shape='rectangle')
    orc.node('dorc', '<<b><u>Dragonsorc</u></b>>')
    orc.node('horc', 'Hopesorc')
    orc.node('sorc', 'Summersorc')
    
    orc.node('eorc', '<<b><u>Endsorc</u></b>>')
    orc.node('worc', 'Wasterorc')
    orc.node('hirc', 'Highsorc')
    
    orc.node('werc', '<<b><u>Windsorc</u></b>>')
    orc.node('porc', 'Persorc')
    orc.node('vorc', 'Vestorc')
    orc.node('aorc', 'Ahmsorc')
    
    orc.node('farc', '<<b><u>Farsorc</u></b>>')
    orc.node('borc', 'Bastionsorc')
    orc.node('surc', 'Southsorc')

    orc.node('iorc', '<<b><u>Islander Orc</u></b>>')
    
    orc.edge('orc', 'dorc', arrowhead='vee')
    orc.edge('dorc', 'horc', arrowhead='diamond')
    orc.edge('dorc', 'sorc', arrowhead='diamond')
    orc.edge('orc', 'eorc', arrowhead='vee')
    orc.edge('eorc', 'worc', arrowhead='diamond')
    orc.edge('eorc', 'hirc', arrowhead='diamond')
    orc.edge('orc', 'werc', arrowhead='vee')
    orc.edge('werc', 'porc', arrowhead='diamond')
    orc.edge('werc', 'vorc', arrowhead='diamond')
    orc.edge('werc', 'aorc', arrowhead='diamond')
    orc.edge('orc', 'farc', arrowhead='vee')
    orc.edge('farc', 'borc', arrowhead='diamond')
    orc.edge('farc', 'surc', arrowhead='diamond')
    orc.edge('orc', 'iorc', arrowhead='vee')

# %%
# Ziva-Gultic root
with dot.subgraph(name='cluster_zvg') as zvg:
    zvg.attr(label='')
    
    zvg.node('zg', '<<b>ZIVA-GULTIC</b>>', shape='rectangle')
    zvg.node('kc', '<<i>Kcalsburian Common</i>>')
    zvg.node('ba', '<<u><b>Barisean</b></u>>')
    zvg.node('mg', 'Modern Gultic')
    zvg.node('pg', 'Pharosian Gultic')
    zvg.node('lg', 'Holm Gultic')
    zvg.node('sg', '<<u><b>Sygultic</b></u>>')
    zvg.node('hc', '<<u><b>Human Common</b></u>>')
    zvg.node('ac', '<<i>Althraxian Common</i>>')
    zvg.node('ho', '<<u><b>Holothetic</b></u>>')
    zvg.node('cz', '<<i>Coszabid</i>>')
    zvg.node('sz', '<<i>Szillian</i>>')
    zvg.node('sn', '<<u><b>Syllan</b></u>>')
    zvg.node('px', '<<u><b>Phraxish</b></u>>')
    zvg.node('fy', '<<u><b>Fyrzish</b></u>>')
    zvg.node('ca', '<<u><b>Cadirzish</b></u>>')
    zvg.node('ad', 'Aedethetic')
    zvg.node('er', 'Erthathetic')
    zvg.node('ma', 'Modern Althraxian')
    
    zvg.edge('zg', 'ac', arrowhead='normal')
    zvg.edge('zg', 'kc', arrowhead='normal')
    
    zvg.edge('ac', 'ho', arrowhead='vee')
    zvg.edge('ho', 'ad', arrowhead='diamond')
    zvg.edge('ho', 'er', arrowhead='diamond')
    zvg.edge('ho', 'ma', arrowhead='diamond')
    zvg.edge('ac', 'cz', arrowhead='vee')
    zvg.edge('cz', 'sz', arrowhead='dot')
    zvg.edge('sz', 'sn', arrowhead='vee')
    zvg.edge('sz', 'px', arrowhead='vee')
    zvg.edge('sz', 'ca', arrowhead='vee')
    zvg.edge('cz', 'fy', arrowhead='vee')
    zvg.edge('kc', 'fy', arrowhead='vee')
    zvg.edge('mg', 'px', arrowhead='vee')
    zvg.edge('kc', 'ba', arrowhead='vee')
    
    zvg.edge('kc', 'ho', arrowhead='vee')
    zvg.edge('kc', 'hc', arrowhead='dot')
    zvg.edge('hc', 'mg', arrowhead='diamond')
    zvg.edge('hc', 'lg', arrowhead='diamond')
    zvg.edge('hc', 'pg', arrowhead='diamond')
    zvg.edge('hc', 'sg', arrowhead='vee')
    zvg.edge('sz', 'sg', arrowhead='vee')

# %%
# Hirsid root
with dot.subgraph(name='cluster_hrs') as hrs:
    hrs.attr(label='')
        
    hrs.node('hi', '<<b>HIRSIAN</b>>', shape='rectangle')
    hrs.node('1h', '<<i>Prime Hirsian</i>>')
    hrs.node('2h', '<<i>Derivative Hirsian</i>>')
    hrs.node('3h', '<<i>High Hirsian</i>>')
    hrs.node('ar', '<<u><b>Arberian</b></u>>')
    hrs.node('uz', '<<u><b>Uzbari</b></u>>')
    hrs.node('ka', '<<u><b>Kandeshi</b></u>>')
    
    hrs.edge('hi', '1h', arrowhead='normal')
    hrs.edge('1h', '2h', arrowhead='dot')
    hrs.edge('1h', 'uz', arrowhead='vee')
    hrs.edge('2h', '3h', arrowhead='dot')
    hrs.edge('2h', 'ka', arrowhead='vee')
    hrs.edge('3h', 'ar', arrowhead='dot')

# %%
# Olmen root
with dot.subgraph(name='cluster_olt') as olt:
    olt.attr(label='')
    
    olt.node('ol', '<<b>OLMEN</b>>', shape='rectangle')
    olt.node('ot', '<<i>Old-Tongue</i>>')
    olt.node('otw', '<<u><b>West Old-Tongue</b></u>>')
    olt.node('ry', 'Rhyder')
    olt.node('wi', 'Wig')
    olt.node('pt', 'Picaty')
    olt.node('vl', 'Valsh')
    olt.node('ote', '<<u><b>East Old-Tongue</b></u>>')
    olt.node('cy', 'Cyrrish')
    olt.node('my', 'Myddish')
    olt.node('otn', '<<u><b>North Old-Tongue</b></u>>')
    olt.node('ak', 'Althriki')
    olt.node('kb', 'Kulbeki')
    olt.node('oty', '<<u><b>Yelentsi</b></u>>')
    olt.node('sk', '<<i>Skoltslang</i>>')
    olt.node('ae', '<<u><b>Aedenslang</b></u>>')
    olt.node('no', '<<u><b>Norslang</b></u>>')
    olt.node('fs', 'Fyrslang')
    olt.node('ul', 'Ulmiric')
    olt.node('st', 'Styolbeki')
    
    olt.edge('ol', 'ot', arrowhead='normal')
    olt.edge('ol', 'sk', arrowhead='normal')
    olt.edge('sk', 'ae', arrowhead='vee')
    olt.edge('sk', 'no', arrowhead='vee')
    olt.edge('ot', 'otw', arrowhead='vee')
    olt.edge('otw', 'ry', arrowhead='diamond')
    olt.edge('otw', 'wi', arrowhead='diamond')
    olt.edge('otw', 'pt', arrowhead='diamond')
    olt.edge('otw', 'vl', arrowhead='diamond')
    olt.edge('ot', 'ote', arrowhead='vee')
    olt.edge('ote', 'cy', arrowhead='diamond')
    olt.edge('ote', 'my', arrowhead='diamond')
    olt.edge('ot', 'otn', arrowhead='vee')
    olt.edge('otn', 'ak', arrowhead='diamond')
    olt.edge('otn', 'kb', arrowhead='diamond')
    olt.edge('ot', 'oty', arrowhead='vee')
    olt.edge('otw', 'ul', arrowhead='vee')
    olt.edge('ote', 'ul', arrowhead='diamond')
    olt.edge('otn', 'st', arrowhead='diamond')
    olt.edge('sk', 'st', arrowhead='vee')
    olt.edge('sk', 'fs', arrowhead='vee')

# %%
# Dwarven root
with dot.subgraph(name='cluster_dwr') as dwr:
    dwr.attr(label='')
        
    dwr.node('dw', '<<b>DWARVEN</b>>', shape='rectangle')
    dwr.node('dr', '<<i>Darvi</i>>')
    dwr.node('kl', '<<i>Kolvi</i>>')
    dwr.node('od', '<<i>Old Dwarvish</i>>')
    dwr.node('ms', '<<u><b>Minespeak</b></u>>')
    dwr.node('bl', '<<i>Balvi</i>>')
    dwr.node('kr', '<<i>Kharvi</i>>')
    dwr.node('md', '<<i>Mid-Dwarvish</i>>')
    dwr.node('gl', '<<u><b>Galvi</b></u>>')
    dwr.node('hd', '<<i>High Dwarven</i>>')
    dwr.node('nr', '<<i>Norvi</i>>')
    dwr.node('dl', '<<i>Dulvi</i>>')
    dwr.node('hg', '<<u><b>Highgardian</b></u>>')
    dwr.node('dc', '<<u><b>Dwarven Common</b></u>>')
    
    dwr.edge('dw', 'dr', arrowhead='normal')
    dwr.edge('dw', 'kl', arrowhead='normal')
    dwr.edge('dr', 'od', arrowhead='box')
    dwr.edge('kl', 'od', arrowhead='box')
    dwr.edge('od', 'ms', arrowhead='vee')
    dwr.edge('od', 'bl', arrowhead='vee')
    dwr.edge('od', 'kr', arrowhead='vee')
    dwr.edge('od', 'md', arrowhead='box')
    dwr.edge('bl', 'md', arrowhead='box')
    dwr.edge('kr', 'md', arrowhead='box')
    dwr.edge('md', 'gl', arrowhead='vee')
    dwr.edge('md', 'nr', arrowhead='vee')
    dwr.edge('md', 'dl', arrowhead='vee')
    dwr.edge('md', 'hd', arrowhead='dot')
    dwr.edge('hd', 'hg', arrowhead='vee')
    dwr.edge('gl', 'dc', arrowhead='box')
    dwr.edge('hd', 'dc', arrowhead='dot')
    dwr.edge('nr', 'dc', arrowhead='box')
    dwr.edge('dl', 'dc', arrowhead='box')
    dwr.edge('hg', 'dc', arrowhead='box')

# %%
# Elven root
with dot.subgraph(name='cluster_elv') as elv:
    elv.attr(label='')
    
    elv.node('e', '<<b>ELVEN</b>>', shape='rectangle')
    elv.node('oe', '<<i>Old Elven</i>>')
    elv.node('me', '<<i>Mid-Elven</i>>')
    elv.node('he', '<<u><b>Delos\'rithei</b></u>>') # Rename
    elv.node('fe', '<<u><b>Sylvaro\'rithei</b></u>>') # Rename
    elv.node('sp', '<<u><b>Sporo\'rithei</b></u>>') # Rename
    elv.node('de', '<<u><b>Karo\'rithei</b></u>>') # Rename
    elv.node('se', '<<u><b>Arobo\'rithei</b></u>>') # Rename

    elv.edge('e', 'oe', arrowhead='normal')
    elv.edge('oe', 'me', arrowhead='dot')
    elv.edge('oe', 'de', arrowhead='vee')
    elv.edge('me', 'he', arrowhead='vee')
    elv.edge('me', 'fe', arrowhead='vee')
    elv.edge('me', 'se', arrowhead='vee')
    elv.edge('me', 'sp', arrowhead='box')
    elv.edge('fe', 'sp', arrowhead='box')

# %%
# Clan-Tongue root
with dot.subgraph(name='cluster_cln') as cln:
    cln.attr(label='')
    
    cln.node('ct', '<<b>CLAN-TONGUE</b>>', shape='rectangle')
    cln.node('go', 'Gobbish')
    cln.node('og', 'Ogrish')
    cln.node('gs', 'Gnolsh')
    cln.node('dg', 'Drogsh')
    cln.node('si', 'Skizzish')
    cln.node('rt', '<<u><b>Ratsign</b></u>>', shape='egg')
    cln.node('cp', '<<u><b>Clanspeech</b></u>>')
    
    cln.edge('ct', 'go', arrowhead='normal')
    cln.edge('ct', 'og', arrowhead='normal')
    cln.edge('ct', 'gs', arrowhead='normal')
    cln.edge('ct', 'dg', arrowhead='normal')
    cln.edge('ct', 'si', arrowhead='normal')
    cln.edge('ct', 'rt', arrowhead='normal')
    cln.edge('go', 'cp', arrowhead='box')
    cln.edge('og', 'cp', arrowhead='box')
    cln.edge('gs', 'cp', arrowhead='box')
    cln.edge('dg', 'cp', arrowhead='box')
    cln.edge('si', 'cp', arrowhead='box')

# %%
# Pharosian root
with dot.subgraph(name='cluster_phr') as phr:
    phr.attr(label='')
    
    phr.node('ph', '<<b>PHAROSIAN</b>>', shape='rectangle')
    phr.node('ep', '<<i>Early Pharosian</i>>')
    phr.node('dv', '<<i>Devanian</i>>')
    phr.node('cd', '<<u><b>Court Devanian</b></u>>')
    phr.node('mt', 'Montean')
    phr.node('lp', '<<i>Late Pharosian</i>>')
    phr.node('ci', 'Ciraelyd')
    phr.node('gn', 'Ganemyd')
    phr.node('rh', 'Rhowyd')
    phr.node('pc', '<<u><b>Pharosian Common</b></u>>')
    
    phr.edge('ph', 'ep', arrowhead='normal')
    phr.edge('ph', 'lp', arrowhead='normal')
    phr.edge('ep', 'mt', arrowhead='vee')
    phr.edge('ep', 'dv', arrowhead='vee')
    phr.edge('dv', 'cd', arrowhead='diamond')
    phr.edge('lp', 'ci', arrowhead='vee')
    phr.edge('lp', 'rh', arrowhead='vee')
    phr.edge('lp', 'gn', arrowhead='vee')
    phr.edge('ci', 'pc', arrowhead='box')
    phr.edge('gn', 'pc', arrowhead='box')
    phr.edge('rh', 'pc', arrowhead='box')
    phr.edge('dv', 'pc', arrowhead='box')
    phr.edge('mt', 'pc', arrowhead='box')

# %%
# Various magical languages
with dot.subgraph(name='cluster_mgc') as mgc:
    mgc.attr(label='')
    
    mgc.node('ra', '<<u><b>Razimric</b></u>>', shape='egg')
    mgc.node('sy', '<<u><b>Sylvan</b></u>>', shape='diamond')
    mgc.node('sh', '<<u><b>Shadaran</b></u>>', shape='diamond')
    mgc.node('dru', '<<u><b>Druidic</b></u>>', shape='egg')
    mgc.node('nc', '<<u><b>Necromantic</b></u>>', shape='egg')
    mgc.node('drc', '<<u><b>Draconic</b></u>>', shape='diamond')
    mgc.node('sr', '<<u><b>Seraphic</b></u>>', shape='diamond')
    
    mgc.edge('ra', 'dru', arrowhead='none')
    mgc.edge('ra', 'nc', arrowhead='none')
    mgc.edge('sr', 'ra', arrowhead='none')
    mgc.edge('sy', 'dru', arrowhead='none')
    mgc.edge('sh', 'nc', arrowhead='none')

# %%
# Now we add language isolates!
dot.node('ki', '<<u><b>Kai\'Rinese</b></u>>', shape='diamond')
dot.node('ve', '<<u><b>Vestali</b></u>>', shape='diamond')
dot.node('chr', '<<u><b>Chirpchant</b></u>>', shape='egg')
dot.node('cht', '<<u><b>Chitterchat</b></u>>', shape='egg')

# %%
# And constructed languages - e.g., ones that were artificially made for one reason or another
dot.node('tr', '<<u><b>Trinean</b></u>>', shape='egg')
dot.node('yip', '<<u><b>Yipyap</b></u>>', shape='egg')

# %%
# Finally we manage the cross-edges, where different language roots influenced languages outside of their group.
dot.edge('ot', 'ph', color='indianred', arrowhead='vee')
dot.edge('oe', 'ph', color='indianred', arrowhead='vee')
dot.edge('ar', 'se', color='indianred', arrowhead='vee')
dot.edge('kc', 'gl', color='indianred', arrowhead='vee')
dot.edge('pg', 'hg', color='indianred', arrowhead='vee')
dot.edge('kc', 'tr', color='indianred', arrowhead='curve')
dot.edge('ve', 'tr', color='indianred', arrowhead='curve')
dot.edge('sh', 'tr', color='indianred', arrowhead='curve')
dot.edge('hc', 'no', color='indianred', arrowhead='vee')
dot.edge('uz', 'ae', color='indianred', arrowhead='vee')
dot.edge('me', 'cd', color='indianred', arrowhead='vee')
dot.edge('ki', 'chr', color='indianred', arrowhead='curve')
dot.edge('sy', 'chr', color='indianred', arrowhead='curve')
dot.edge('sy', 'cht', color='indianred', arrowhead='curve')
dot.edge('oe', 'oty', color='indianred', arrowhead='vee')
dot.edge('sy', 'fe', color='indianred', arrowhead='vee')
dot.edge('he', 'rh', color='indianred', arrowhead='vee')
dot.edge('ep', 'sorc', color='indianred', arrowhead='vee')
dot.edge('se', 'worc', color='indianred', arrowhead='vee')
dot.edge('ve', 'vorc', color='indianred', arrowhead='vee')
dot.edge('ka', 'aorc', color='indianred', arrowhead='vee')
dot.edge('ho', 'surc', color='indianred', arrowhead='vee')
dot.edge('sy', 'yip', color='indianred', arrowhead='curve')
dot.edge('ct', 'yip', color='indianred', arrowhead='curve')
dot.edge('fs', 'fy', color='indianred', arrowhead='vee')

# %% [markdown]
# The graph is now generated. All we need is to instantiate the legend.

# %%
with dot.subgraph(name='cluster_legend') as legend:
    legend.attr(label='LEGEND')
    
    legend.node('Root Language', shape='rectangle')
    legend.node('Language Isolate', shape='diamond')
    legend.node('cl', 'Constructed Language', shape='egg')
    legend.node('pod', 'Divergence', shape='plaintext')
    legend.node('pom', 'Modernization', shape='plaintext')
    legend.node('poi', 'Dialect (Mutually Intelligible)', shape='plaintext')
    legend.node('poc', 'Convergence (Partially Intelligible)', shape='plaintext')
    legend.node('por', 'Relation', shape='plaintext')
    legend.node('pot', 'Construction', shape='plaintext')
    legend.node('dead', '<<i>Dead Language</i>>')
    legend.node('std', '<<b>Standard Use Language</b>>')
    legend.node('dia', 'Dialect or Living Obsolete')
    
    legend.edge('pod', 'pod', arrowhead='vee')
    legend.edge('pom', 'pom', arrowhead='dot')
    legend.edge('poi', 'poi', arrowhead='diamond')
    legend.edge('poc', 'poc', arrowhead='box')
    legend.edge('por', 'por', arrowhead='none')
    legend.edge('pot', 'pot', arrowhead='curve')
    
    legend.edge('cl', 'ct', style='invis')
    legend.edge('cl', 'dw', style='invis')
    legend.edge('cl', 'zg', style='invis')
    legend.edge('cl', 'ol', style='invis')
    legend.edge('cl', 'e', style='invis')
    legend.edge('cl', 'hi', style='invis')
    legend.edge('cl', 'drc', style='invis')
    legend.edge('cl', 'orc', style='invis')

# %% [markdown]
# We can render the result as a png for easy saving.

# %%
dot.render('LanguageTree', view=True, format='png')
# Out:
# 'LanguageTree.png'

# %%
dot
